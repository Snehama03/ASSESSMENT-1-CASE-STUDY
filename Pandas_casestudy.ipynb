# %%
import numpy as np
import pandas as pd

# %%
auto_data=pd.read_csv("/content/moive.csv")

# %%
auto_data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
auto_data.shape
# Out:
# (1000, 12)

# %%
auto_data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
auto_data.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
auto_data.isnull()
# Out:
#       Rank  Title  Genre  Description  Director  Actors   Year  \
# 0    False  False  False        False     False   False  False
# 1    False  False  False        False     False   False  False
# 2    False  False  False        False     False   False  False
# 3    False  False  False        False     False   False  False
# 4    False  False  False        False     False   False  False
# ..     ...    ...    ...          ...       ...     ...    ...
# 995  False  False  False        False     False   False  False
# 996  False  False  False        False     False   False  False
# 997  False  False  False        False     False   False  False
# 998  False  False  False        False     False   False  False
# 999  False  False  False        False     False   False  False
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 0                False   False  False               False      False
# 1                False   False  False               False      False
# ...

# %%
auto_data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
auto_data.drop_duplicates()
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
auto_data.rename(columns={'Title': 'Movie_Title'}, inplace=True)

# %%
auto_data
# Out:
#      Rank              Movie_Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
auto_data['Genre'].unique()
# Out:
# array(['Action,Adventure,Sci-Fi', 'Adventure,Mystery,Sci-Fi',
#        'Horror,Thriller', 'Animation,Comedy,Family',
#        'Action,Adventure,Fantasy', 'Comedy,Drama,Music', 'Comedy',
#        'Action,Adventure,Biography', 'Adventure,Drama,Romance',
#        'Adventure,Family,Fantasy', 'Biography,Drama,History',
#        'Animation,Adventure,Comedy', 'Action,Comedy,Drama',
#        'Action,Thriller', 'Biography,Drama', 'Drama,Mystery,Sci-Fi',
#        'Adventure,Drama,Thriller', 'Drama', 'Crime,Drama,Horror',
#        'Action,Adventure,Drama', 'Drama,Thriller',
#        'Action,Adventure,Comedy', 'Action,Horror,Sci-Fi',
#        'Adventure,Drama,Sci-Fi', 'Action,Adventure,Western',
#        'Comedy,Drama', 'Horror', 'Adventure,Drama,Fantasy',
#        'Action,Crime,Thriller', 'Action,Crime,Drama',
#        'Adventure,Drama,History', 'Crime,Horror,Thriller',
#        'Drama,Romance', 'Comedy,Drama,Romance', 'Horror,Mystery,Thriller',
# ...

# %%
auto_data['Genre'].value_counts()
# Out:
# Genre
# Action,Adventure,Sci-Fi     50
# Drama                       48
# Comedy,Drama,Romance        35
# Comedy                      32
# Drama,Romance               31
#                             ..
# Drama,Fantasy,Musical        1
# Adventure,Family             1
# Adventure,Comedy,Fantasy     1
# Drama,Family,Music           1
# Comedy,Family,Fantasy        1
# Name: count, Length: 207, dtype: int64

# %%
auto_data['Revenue (Millions)'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998     True
# 999    False
# Name: Revenue (Millions), Length: 1000, dtype: bool

# %%
auto_data['Metascore'].isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: Metascore, Length: 1000, dtype: bool

# %%
top_5 = auto_data.sort_values(by='Rating', ascending=False).head(5)
print(top_5[['Movie_Title', 'Rating']])
# Out:
#           Movie_Title  Rating
# 54    The Dark Knight     9.0
# 80          Inception     8.8
# 117            Dangal     8.8
# 36       Interstellar     8.6
# 249  The Intouchables     8.6

# %%
auto_data.sort_values(by='Revenue (Millions)', ascending=False).head(1)
# Out:
#     Rank                                 Movie_Title  \
# 50    51  Star Wars: Episode VII - The Force Awakens
#
#                        Genre  \
# 50  Action,Adventure,Fantasy
#
#                                           Description     Director  \
# 50  Three decades after the defeat of the Galactic...  J.J. Abrams
#
#                                                Actors  Year  \
# 50  Daisy Ridley, John Boyega, Oscar Isaac, Domhna...  2015
#
#     Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 50                136     8.1  661608              936.63       81.0

# %%
auto_data.sort_values(by='Revenue (Millions)', ascending=True).head(1)
# Out:
#      Rank       Movie_Title                 Genre  \
# 231   232  A Kind of Murder  Crime,Drama,Thriller
#
#                                            Description      Director  \
# 231  In 1960s New York, Walter Stackhouse is a succ...  Andy Goddard
#
#                                                 Actors  Year  \
# 231  Patrick Wilson, Jessica Biel, Haley Bennett, V...  2016
#
#      Runtime (Minutes)  Rating  Votes  Revenue (Millions)  Metascore
# 231                 95     5.2   3305                 0.0       50.0

# %%
avg_rating_by_director = auto_data.groupby('Director')['Rating'].mean().sort_values(ascending=False)
print("Average Rating by Director:\n", avg_rating_by_director.head())
# Out:
# Average Rating by Director:
#  Director
# Nitesh Tiwari                       8.80
# Christopher Nolan                   8.68
# Olivier Nakache                     8.60
# Makoto Shinkai                      8.60
# Florian Henckel von Donnersmarck    8.50
# Name: Rating, dtype: float64

# %%
movies_per_year = auto_data['Year'].value_counts().sort_index()
print("Movies per Year:\n", movies_per_year)
# Out:
# Movies per Year:
#  Year
# 2006     44
# 2007     53
# 2008     52
# 2009     51
# 2010     60
# 2011     63
# 2012     64
# 2013     91
# 2014     98
# 2015    127
# 2016    297
# Name: count, dtype: int64

# %%
high_rated_high_revenue_movies = auto_data[(auto_data['Rating'] > 8) & (auto_data['Revenue (Millions)'] > 100)]
print("Movies with Rating > 8 and Revenue > 100M:\n")
print(high_rated_high_revenue_movies[['Movie_Title', 'Rating', 'Revenue (Millions)']])
# Out:
# Movies with Rating > 8 and Revenue > 100M:
#
#                                       Movie_Title  Rating  Revenue (Millions)
# 0                         Guardians of the Galaxy     8.1              333.13
# 6                                      La La Land     8.3              151.06
# 36                                   Interstellar     8.6              187.99
# 50     Star Wars: Episode VII - The Force Awakens     8.1              936.63
# 54                                The Dark Knight     9.0              533.32
# 67                             Mad Max: Fury Road     8.1              153.63
# 74                                       Zootopia     8.1              341.26
# 76                                   The Avengers     8.1              623.28
# 77                           Inglourious Basterds     8.3              120.52
# 80                                      Inception     8.8              292.57
# ...

# %%
director_stats = auto_data.groupby('Director').agg(
    avg_rating=('Rating', 'mean'),
    total_revenue=('Revenue (Millions)', 'sum')
).sort_values(by='avg_rating', ascending=False)

print("Director Statistics (Average Rating and Total Revenue):\n")
print(director_stats.head())
# Out:
# Director Statistics (Average Rating and Total Revenue):
#
#                                   avg_rating  total_revenue
# Director
# Nitesh Tiwari                           8.80          11.15
# Christopher Nolan                       8.68        1515.09
# Olivier Nakache                         8.60          13.18
# Makoto Shinkai                          8.60           4.68
# Florian Henckel von Donnersmarck        8.50          11.28

# %%
movies_by_year_stats = auto_data.groupby('Year').agg(
    movie_count=('Movie_Title', 'count'),
    avg_rating=('Rating', 'mean')
).sort_values(by='Year', ascending=True)

print("Movies by Year Statistics (Count and Average Rating):\n")
print(movies_by_year_stats)
# Out:
# Movies by Year Statistics (Count and Average Rating):
#
#       movie_count  avg_rating
# Year
# 2006           44    7.125000
# 2007           53    7.133962
# 2008           52    6.784615
# 2009           51    6.960784
# 2010           60    6.826667
# 2011           63    6.838095
# 2012           64    6.925000
# 2013           91    6.812088
# 2014           98    6.837755
# 2015          127    6.602362
# 2016          297    6.436700

# %%
#Create a new column 'Profitability' (Revenue per minute)
auto_data['Profitability'] = auto_data['Revenue (Millions)'] / auto_data['Runtime (Minutes)']

# Find the top 10 most profitable movies
top_10_profitable_movies = auto_data.sort_values(by='Profitability', ascending=False).head(10)

print("Top 10 Most Profitable Movies (Revenue per Minute):\n")
print(top_10_profitable_movies[['Movie_Title', 'Profitability']])
# Out:
# Top 10 Most Profitable Movies (Revenue per Minute):
#
#                                     Movie_Title  Profitability
# 50   Star Wars: Episode VII - The Force Awakens       6.886985
# 85                               Jurassic World       5.259516
# 119                                Finding Dory       5.013299
# 87                                       Avatar       4.694506
# 76                                 The Avengers       4.358601
# 15                      The Secret Life of Pets       4.233448
# 688                                 Toy Story 3       4.028932
# 12                                    Rogue One       4.001278
# 174                                      Frozen       3.928824
# 797                             Despicable Me 2       3.755612

# %%
# Define the conditions for categorization
conditions = [
    (auto_data['Rating'] < 6),
    (auto_data['Rating'] >= 6) & (auto_data['Rating'] < 7.5),
    (auto_data['Rating'] >= 7.5)
]

# Define the corresponding categories
choices = ['Poor', 'Average', 'Excellent']

# Create the new 'Rating_Category' column
auto_data['Rating_Category'] = np.select(conditions, choices, default='Unknown')

# Display the count of movies in each category
print("Distribution of movies by Rating Category:\n")
print(auto_data['Rating_Category'].value_counts())
# Out:
# Distribution of movies by Rating Category:
#
# Rating_Category
# Average      586
# Excellent    230
# Poor         184
# Name: count, dtype: int64

# %% [markdown]
# ###Custom Movie Scoring Function
# I will now create a custom function to calculate a 'Movie_Score' for each movie based on its 'Rating' and 'Revenue (Millions)' using the formula: Rating * 10 + Revenue (Millions). This function will then be applied to the DataFrame to create a new column.

# %%
def calculate_movie_score(row):
    # Ensure 'Revenue (Millions)' is treated as 0 if NaN for scoring purposes
    revenue = row['Revenue (Millions)'] if pd.notna(row['Revenue (Millions)']) else 0
    return (row['Rating'] * 10) + revenue

# Apply the custom function to create the 'Movie_Score' column
auto_data['Movie_Score'] = auto_data.apply(calculate_movie_score, axis=1)

# Display the top 10 movies based on this new score
print("Top 10 Movies by Custom Score:\n")
print(auto_data[['Movie_Title', 'Rating', 'Revenue (Millions)', 'Movie_Score']].sort_values(by='Movie_Score', ascending=False).head(10))
# Out:
# Top 10 Movies by Custom Score:
#
#                                     Movie_Title  Rating  Revenue (Millions)  \
# 50   Star Wars: Episode VII - The Force Awakens     8.1              936.63
# 87                                       Avatar     7.8              760.51
# 85                               Jurassic World     7.0              652.18
# 76                                 The Avengers     8.1              623.28
# 54                              The Dark Knight     9.0              533.32
# 12                                    Rogue One     7.9              532.17
# 119                                Finding Dory     7.4              486.29
# 124                       The Dark Knight Rises     8.5              448.13
# 94                      Avengers: Age of Ultron     7.4              458.99
# 578             The Hunger Games: Catching Fire     7.6              424.65
#
#      Movie_Score
# 50       1017.63
# 87        838.51
# 85        722.18
# 76        704.28
# ...
